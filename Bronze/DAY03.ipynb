# %%
import  pandas

# %%
sourceFileUrl="/Workspace/Users/databrickslearning30days@gmail.com/AZURE-Databricks/Bronze/BronzeIngest.csv"

# %% [markdown]
# Reading **CSV** File using **Pandas**

# %%
sourceFileDF=pandas.read_csv(sourceFileUrl)

# %% [markdown]
# Created **DataFrame** from Read **CSV**

# %%
sourceFileSparkDF=spark.createDataFrame(sourceFileDF)

# %%
BRONZE_PATH = "/Volumes/workspace/default/lakehouse"
SILVER_PATH = "dbfs:/FileStore/lakehouse/silver/sales"
GOLD_PATH   = "dbfs:/FileStore/lakehouse/gold/sales"

# %%
display(BRONZE_PATH)

# %%
(sourceFileSparkDF.write
  .mode("overwrite")
  .option("header", "true")
  .csv(BRONZE_PATH))
